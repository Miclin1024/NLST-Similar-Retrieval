# %%
from data import *

reader = NLSTDataReader(manifest=1663396252954)
reader.visualize(100004)
result = reader.read_uid('1.2.840.113654.2.55.122344168497038128022524906545138736420')
print(result.shape)
# Out:
# 01-02-1999 (5/118 slices chosen uniformly within each scan):
# 01-02-2000 (5/109 slices chosen uniformly within each scan):
# 01-02-2001 (5/150 slices chosen uniformly within each scan):
# (128, 128, 128)
